# %%
import gdown

# %%
url="https://drive.google.com/file/d/1xJYnY4uHuxdw9IjQ1Ej3g0CP4dspKCqz/view?usp=sharing"

# %%
file_id=url.split("/")[-2]
file_id
# Out:
# '1xJYnY4uHuxdw9IjQ1Ej3g0CP4dspKCqz'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "kidney-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1xJYnY4uHuxdw9IjQ1Ej3g0CP4dspKCqz
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1xJYnY4uHuxdw9IjQ1Ej3g0CP4dspKCqz&confirm=t&uuid=9cc15529-b42a-4e5f-8b89-c441dae58f40
# To: c:\Users\karakkir\OneDrive - Tietoevry\Kidney-dl\research\kidney-CT-Scan-data.zip
# 100%|██████████| 57.7M/57.7M [00:05<00:00, 9.86MB/s]
# 'kidney-CT-Scan-data.zip'
